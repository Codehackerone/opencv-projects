# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread('../DATA/internal_external.png')
plt.imshow(img)

# %%
image,contours,hierarchy=cv2.findContours(img,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-7527630aeed2> in <module>
# ----> 1 image,contours,hierarchy=cv2.findContours(img,cv2.RETR_FLOODFILL,cv2.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.5.1) /private/var/folders/9d/1znl6gwn1g9dfd57ts6tsjgc0000gn/T/pip-install-mg68o28i/opencv-python_8f784b0ac0ff463a95b225235125a5aa/opencv/modules/imgproc/src/contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
